# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #creating dataset

# %%
data = {
    "area": [800, 1000, 1200, 1500, 1800, 2000, 2200, 2500, 2800, 3000],
    "bedroom": [2, 2, 3, 3, 3, 4, 4, 4, 5, 5],
    "bathroom": [1, 2, 2, 2, 3, 3, 3, 4, 4, 5],
    "price": [35, 45, 55, 65, 80, 95, 110, 125, 145, 165]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    area  bedroom  bathroom  price
# 0   800        2         1     35
# 1  1000        2         2     45
# 2  1200        3         2     55
# 3  1500        3         2     65
# 4  1800        3         3     80

# %%
X = df.iloc[:,0:3]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    area  bedroom  bathroom
# 0   800        2         1
# 1  1000        2         2
# 2  1200        3         2
# 3  1500        3         2
# 4  1800        3         3

# %%
y.head()
# Out:
# 0    35
# 1    45
# 2    55
# 3    65
# 4    80
# Name: price, dtype: int64

# %% [markdown]
# ## Using Sklearn's Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (8, 3)
# (2, 3)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8223852040816344

# %%
reg.coef_
# Out:
# array([0.04375   , 0.41666667, 8.33333333])

# %%
reg.intercept_
# Out:
# np.float64(-14.687500000000355)

# %% [markdown]
# ## Making our own Linear Regression Class

# %% [markdown]
# betas = <br>
# np.linalg.<br>
# inv(np.dot(X_train.T,X_train))<br>
# .dot(X_train.T)<br>
# .dot(y_train)<br>

# %%
class NITR_MLR:

    def __init__(self):
        self.coef_ = None
        self.intercept_ = None

    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)  # adding a column (beta 0) at index 0

        # calcuate the coeffs
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]

    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %%
lr = NITR_MLR()

# %%
lr.fit(X_train,y_train)

# %%
X_train.shape
# Out:
# (8, 3)

# %%
np.insert(X_train,0,1,axis=1).shape
# Out:
# (8, 4)

# %%
y_pred = lr.predict(X_test)

# %%
mse = np.mean((y_test - y_pred) ** 2)
mae = np.mean((y_test - y_pred))
r2 = 1 - (mse)/np.mean((y_test - np.average(y_test))**2)
mse,mae,r2
# Out:
# (np.float64(54.39453124992267),
#  np.float64(-5.937499999993676),
#  np.float64(0.8223852040818851))

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8223852040818851

# %% [markdown]
# #compare NITR_MLR and skLearn

# %%
lr.coef_,reg.coef_
# Out:
# (array([0.04375   , 0.41666667, 8.33333333]),
#  array([0.04375   , 0.41666667, 8.33333333]))

# %%
lr.intercept_,reg.intercept_
# Out:
# (np.float64(-14.687500000005059), np.float64(-14.687500000000355))
